# %%
# %pip install jsonschema pathspec
# Out:
# Requirement already satisfied: jsonschema in c:\users\sathish\anaconda3\envs\llm_lab\lib\site-packages (4.23.0)
# Requirement already satisfied: pathspec in c:\users\sathish\anaconda3\envs\llm_lab\lib\site-packages (0.12.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sathish\anaconda3\envs\llm_lab\lib\site-packages (from jsonschema) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sathish\anaconda3\envs\llm_lab\lib\site-packages (from jsonschema) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sathish\anaconda3\envs\llm_lab\lib\site-packages (from jsonschema) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sathish\anaconda3\envs\llm_lab\lib\site-packages (from jsonschema) (0.22.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\sathish\anaconda3\envs\llm_lab\lib\site-packages (from referencing>=0.28.4->jsonschema) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Documentation for Directory Structure Automation
#
# ## Overview
# This document details the process of creating, optimizing, and updating a Python script to manage directory structures. The focus is on implementing an automated and robust system for:
# - Reading and updating directory structures.
# - Generating and maintaining a JSON representation of the structure.
# - Ensuring minimal redundancy and efficient file handling.
#
# The document includes brainstorming ideas, optimizations, and implementation changes that were incorporated throughout the development process.
#
# ---
#
# ## Initial Requirements
#
# ### Goals:
# 1. Automate the creation of a directory structure.
# 2. Generate a JSON file to represent the directory structure.
# 3. Allow updates to the JSON file to reflect changes in the directory.
# 4. Avoid modifying existing files or directories unnecessarily.
# 5. Handle potential errors, including malformed JSON or missing files.
#
# ---
#
# ## Brainstorming and Challenges
#
# ### Key Questions Addressed:
# 1. **How to handle existing files and directories?**
#    - Avoid overwriting existing directories or files unless explicitly needed.
#    - Ensure efficient comparison of current and saved directory structures.
#
# 2. **How to optimize the update process?**
#    - Compare the current structure with the saved structure in the JSON file.
#    - Update only if differences are detected.
#
# 3. **Error Handling:**
#    - Manage scenarios where the JSON file is missing or corrupted.
#    - Ensure graceful fallback and minimal disruption to the workflow.
#
# 4. **Cross-Platform Compatibility:**
#    - Ensure the script works seamlessly on Windows, Linux, and macOS.
#    - Normalize directory paths for compatibility.
#
# ---
#
# ## Changes and Optimizations
#
# ### Initial Implementation:
# - A script to create directory structures and save them to a JSON file.
# - Basic support for generating placeholder files in directories.
#
# ### Optimizations:
# 1. **Addition of README.md Files:**
#    - Automatically create a `README.md` file in each main directory.
#    - Populate the file with a brief description of the directory's purpose.
#
# 2. **Efficient Updates to JSON File:**
#    - Compare the current directory structure with the saved JSON.
#    - Update the JSON file only if changes are detected.
#    - Skip redundant writes to minimize processing time.
#
# 3. **Cross-Platform Improvements:**
#    - Normalize directory paths using `os.path.relpath` and ensure compatibility with Windows (`\`) and Unix-based systems (`/`).
#
# 4. **Enhanced Error Handling:**
#    - Gracefully handle missing or corrupted JSON files.
#    - Provide clear error messages and fallback mechanisms.
#
# 5. **Dynamic Clearing of Terminal Output:**
#    - Added OS-specific commands to clear the terminal screen before displaying prompts (`cls` for Windows, `clear` for Linux/macOS).
#
# 6. **Modularization:**
#    - Split functionalities into separate functions to improve readability and reusability.
#    - Functions include: `get_directory_structure`, `generate_structure_file`, `create_project_structure`, `update_json_file`, and `load_structure_from_file`.
#
# ---
#
# ## Final Implementation
#
# ### Core Features:
# 1. **Directory Scanning and Structure Generation:**
#    - Recursively scans directories to generate a nested dictionary representation of the structure.
#
# 2. **JSON File Management:**
#    - Reads the existing JSON file.
#    - Updates the file only if changes are detected in the directory structure.
#
# 3. **README.md Generation:**
#    - Creates a `README.md` file in each main directory with relevant descriptions.
#
# 4. **Cross-Platform Compatibility:**
#    - Supports Windows, Linux, and macOS.
#
# 5. **Error Handling:**
#    - Manages missing files, malformed JSON, and other edge cases gracefully.
#
# ---
#
# ## Implementation Details
#
# ### Key Functions:
# 1. **`get_directory_structure`:**
#    - Scans a directory and generates a nested dictionary structure.
#
# 2. **`generate_structure_file`:**
#    - Saves the generated structure to a JSON file.
#
# 3. **`create_project_structure`:**
#    - Creates directories and placeholder files based on a given dictionary structure.
#
# 4. **`update_json_file`:**
#    - Updates the JSON file to reflect the latest directory structure, deleting outdated content if necessary.
#
# 5. **`load_structure_from_file`:**
#    - Loads the JSON file and returns its contents, handling errors for missing or malformed files.
#
# ---
#
# ## Future Enhancements
#
# ### Potential Improvements:
# 1. **Logging:**
#    - Add detailed logging for operations such as file creation, updates, and errors.
#
# 2. **Parallel Processing:**
#    - Use multithreading to improve performance when scanning large directories.
#
# 3. **Customizable Directory Templates:**
#    - Allow users to define custom templates for directory and file structures.
#
# 4. **Interactive CLI:**
#    - Enhance the CLI with options for interactive configuration of directories and files.
#
# ---
#
# ## Conclusion
# This project demonstrates a robust approach to automating directory structure management. By incorporating efficient update mechanisms, error handling, and cross-platform compatibility, the solution is well-suited for diverse use cases. The outlined future enhancements will further improve its utility and scalability.

# %%
import os
import json
import platform
import logging
from concurrent.futures import ThreadPoolExecutor
from jsonschema import validate, ValidationError
from pathspec import PathSpec

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.FileHandler("structure_tool.log"), logging.StreamHandler()],
)

# JSON structure schema for validation
STRUCTURE_SCHEMA = {
    "type": "object",
    "patternProperties": {
        ".*": {
            "anyOf": [
                {"type": "object"},
                {"type": "array", "items": {"type": "string"}}
            ]
        }
    }
}

# Templates for common files
TEMPLATES = {
    "README.md": "# {directory}\n\nThis directory contains resources related to {directory}.",
    "main.py": "# Entry point for the application\n\nif __name__ == '__main__':\n    print('Hello, World!')"
}

def load_gitignore_patterns(root_dir):
    """
    Loads .gitignore patterns using pathspec for efficient pattern matching.
    """
    gitignore_path = os.path.join(root_dir, ".gitignore")
    if os.path.exists(gitignore_path):
        with open(gitignore_path, 'r') as gitignore:
            return PathSpec.from_lines("gitwildmatch", gitignore)
    return None

def should_ignore(path, spec):
    """
    Checks if a path should be ignored based on the .gitignore spec.
    """
    return spec.match_file(path) if spec else False

def validate_structure(structure):
    """
    Validates the JSON structure against the predefined schema.
    """
    try:
        validate(instance=structure, schema=STRUCTURE_SCHEMA)
        logging.info("JSON structure is valid.")
    except ValidationError as e:
        logging.error(f"Invalid JSON structure: {e.message}")
        raise

def get_directory_structure(root_dir):
    """
    Optimized directory traversal using os.scandir.
    """
    spec = load_gitignore_patterns(root_dir)
    structure = {}

    def scan_dir(path, current):
        with os.scandir(path) as it:
            for entry in it:
                relative_path = os.path.relpath(entry.path, root_dir).replace("\\", "/")
                if should_ignore(relative_path, spec):
                    continue
                if entry.is_dir():
                    current[entry.name] = {}
                    scan_dir(entry.path, current[entry.name])
                else:
                    current.setdefault("", []).append(entry.name)

    scan_dir(root_dir, structure)
    return structure

def generate_structure_file(root_dir, output_file="structure.json"):
    """
    Generates a JSON file representing the directory structure of the given root directory.
    """
    structure = get_directory_structure(root_dir)
    with open(output_file, 'w') as f:
        json.dump(structure, f, indent=4)
    logging.info(f"Directory structure saved to {output_file}")

def create_file_with_template(file_path, directory_name):
    """
    Creates a file with predefined content based on its name.
    """
    file_name = os.path.basename(file_path)
    content = TEMPLATES.get(file_name, "")
    with open(file_path, 'w') as f:
        f.write(content.format(directory=directory_name))

def create_project_structure(base_path, structure, dry_run=False):
    """
    Creates a project directory structure or prints it in dry-run mode.
    Skips existing directories and files to avoid redundant operations.
    """
    def create_files_and_dirs(base, items):
        for key, value in items.items():
            current_path = os.path.join(base, key)
            if isinstance(value, dict):  # A directory with subdirectories
                if not os.path.exists(current_path):
                    if dry_run:
                        logging.info(f"Would create directory: {current_path}")
                    else:
                        os.makedirs(current_path, exist_ok=True)
                        logging.info(f"Created directory: {current_path}")
                    # Create a README.md for new directories
                    readme_path = os.path.join(current_path, "README.md")
                    if not os.path.exists(readme_path):
                        if dry_run:
                            logging.info(f"Would create file: {readme_path}")
                        else:
                            create_file_with_template(readme_path, key)
                create_files_and_dirs(current_path, value)
            elif isinstance(value, list):  # A directory with files
                if not os.path.exists(current_path):
                    if dry_run:
                        logging.info(f"Would create directory: {current_path}")
                    else:
                        os.makedirs(current_path, exist_ok=True)
                        logging.info(f"Created directory: {current_path}")
                for file in value:
                    file_path = os.path.join(current_path, file)
                    if not os.path.exists(file_path):
                        if dry_run:
                            logging.info(f"Would create file: {file_path}")
                        else:
                            open(file_path, 'w').close()
                            logging.info(f"Created file: {file_path}")
                    else:
                        logging.info(f"Skipped existing file: {file_path}")

    create_files_and_dirs(base_path, structure)

def load_structure_from_file(file_path):
    """
    Loads a project structure from a JSON file.
    """
    with open(file_path, 'r') as f:
        return json.load(f)

# %%
def main():
    os_type = platform.system()
    logging.info(f"Operating System detected: {os_type}")
    print("Choose an option:")
    print(" - create: Create a new project structure from a JSON file")
    print(" - extract: Extract an existing directory structure to a JSON file")
    print(" - dry-run: Preview the directory structure without creating it")
    choice = input("Enter your choice (create, extract, dry-run): ").strip().lower()

    if choice == "create":
        json_file_path = input("Enter the path to the JSON file defining the structure: ").strip()
        if not json_file_path:
            logging.error("No JSON file path provided.")
            return
        base_directory = input("Enter the base directory for the new project: ").strip()
        if not base_directory:
            logging.error("No base directory provided.")
            return

        if os.path.isfile(json_file_path):
            structure = load_structure_from_file(json_file_path)
            validate_structure(structure)
            create_project_structure(base_directory, structure)
            logging.info(f"Project structure created at {os.path.abspath(base_directory)}")
        else:
            logging.error(f"The file '{json_file_path}' does not exist.")

    elif choice == "extract":
        root_directory = input("Enter the directory to scan: ").strip()
        if not root_directory:
            logging.error("No root directory provided.")
            return
        output_file = input("Enter the output file name (default: structure.json): ").strip() or "structure.json"

        if os.path.isdir(root_directory):
            generate_structure_file(root_directory, output_file)
        else:
            logging.error(f"The directory '{root_directory}' does not exist.")

    elif choice == "dry-run":
        json_file_path = input("Enter the path to the JSON file defining the structure: ").strip()
        if not json_file_path:
            logging.error("No JSON file path provided.")
            return
        base_directory = input("Enter the base directory to preview the structure: ").strip()
        if not base_directory:
            logging.error("No base directory provided.")
            return

        if os.path.isfile(json_file_path):
            structure = load_structure_from_file(json_file_path)
            validate_structure(structure)
            create_project_structure(base_directory, structure, dry_run=True)
        else:
            logging.error(f"The file '{json_file_path}' does not exist.")

    else:
        logging.error("Invalid choice. Please enter 'create', 'extract', or 'dry-run'.")

# %%
if __name__ == "__main__":
    os_type = platform.system()
    if os_type == "Windows":
        os.system("cls")
    elif os_type in ["Linux", "Darwin"]:
        os.system("clear")
    main()
# Out:
# 2025-01-25 21:34:40,966 - INFO - Operating System detected: Windows
# Choose an option:
#  - create: Create a new project structure from a JSON file
#  - extract: Extract an existing directory structure to a JSON file
#  - dry-run: Preview the directory structure without creating it
# 2025-01-25 21:35:09,689 - INFO - JSON structure is valid.
# 2025-01-25 21:35:09,689 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\agents
# 2025-01-25 21:35:09,691 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\agents\__init__.py
# 2025-01-25 21:35:09,691 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\agents\agent.py
# 2025-01-25 21:35:09,692 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\agents\multi_agent_manager.py
# 2025-01-25 21:35:09,692 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\agents\agent_state_manager.py
# 2025-01-25 21:35:09,693 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\agents\agent_collaboration.py
# 2025-01-25 21:35:09,693 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\agents\bureaucracy_agent.py
# 2025-01-25 21:35:09,694 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools
# 2025-01-25 21:35:09,695 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools
# 2025-01-25 21:35:09,695 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\nlp
# 2025-01-25 21:35:09,696 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\nlp\text_summary_tool.py
# 2025-01-25 21:35:09,696 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\nlp\sentiment_analysis_tool.py
# 2025-01-25 21:35:09,696 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\media
# 2025-01-25 21:35:09,697 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\media\text_to_image_tool.py
# 2025-01-25 21:35:09,697 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\media\audio_processing_tool.py
# 2025-01-25 21:35:09,698 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\workflow
# 2025-01-25 21:35:09,698 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\workflow\document_parser_tool.py
# 2025-01-25 21:35:09,699 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\workflow\approval_pipeline_tool.py
# 2025-01-25 21:35:09,699 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tools\workflow\compliance_checker_tool.py
# 2025-01-25 21:35:09,700 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools\chains
# 2025-01-25 21:35:09,701 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\chains\custom_chain.py
# 2025-01-25 21:35:09,701 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\chains\retrieval_chain.py
# 2025-01-25 21:35:09,702 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\chains\decision_chain.py
# 2025-01-25 21:35:09,703 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\chains\rag_chain.py
# 2025-01-25 21:35:09,703 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\chains\approval_chain.py
# 2025-01-25 21:35:09,704 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\chains\compliance_chain.py
# 2025-01-25 21:35:09,704 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools\prompts
# 2025-01-25 21:35:09,705 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\prompts\default_prompt.py
# 2025-01-25 21:35:09,705 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\prompts\system_prompt.py
# 2025-01-25 21:35:09,706 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\prompts\custom_prompt_library.py
# 2025-01-25 21:35:09,706 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\prompts\approval_prompt.py
# 2025-01-25 21:35:09,706 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\prompts\compliance_prompt.py
# 2025-01-25 21:35:09,706 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\langchain_tools\memory
# 2025-01-25 21:35:09,708 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\memory\vector_memory.py
# 2025-01-25 21:35:09,709 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\memory\long_term_memory.py
# 2025-01-25 21:35:09,709 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\memory\document_context_memory.py
# 2025-01-25 21:35:09,711 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\__init__.py
# 2025-01-25 21:35:09,712 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\tool_loader.py
# 2025-01-25 21:35:09,712 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\langchain_tools\langchain_config.py
# 2025-01-25 21:35:09,712 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\mlflow_integration
# 2025-01-25 21:35:09,713 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\mlflow_integration\__init__.py
# 2025-01-25 21:35:09,714 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\mlflow_integration\mlflow_manager.py
# 2025-01-25 21:35:09,714 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\mlflow_integration\tracking.py
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\mlflow_integration\model_loader.py
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\mlflow_integration\model_fine_tuner.py
# 2025-01-25 21:35:09,715 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\analytics
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\analytics\agent_monitor.py
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\analytics\data_visualizer.py
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\analytics\anomaly_detection.py
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\analytics\workflow_monitor.py
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\analytics\compliance_report.py
# 2025-01-25 21:35:09,715 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\security
# 2025-01-25 21:35:09,715 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\security\auth
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\security\auth\authentication.py
# 2025-01-25 21:35:09,715 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\security\auth\authorization.py
# 2025-01-25 21:35:09,715 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\security\document
# 2025-01-25 21:35:09,722 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\security\document\document_access_control.py
# 2025-01-25 21:35:09,722 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\security\rbac_config.py
# 2025-01-25 21:35:09,722 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\tasks
# 2025-01-25 21:35:09,722 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tasks\task_scheduler.py
# 2025-01-25 21:35:09,724 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tasks\priority_task_queue.py
# 2025-01-25 21:35:09,725 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tasks\reminder_job.py
# 2025-01-25 21:35:09,725 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tasks\compliance_job.py
# 2025-01-25 21:35:09,726 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\api_integration
# 2025-01-25 21:35:09,726 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\api_integration\v1
# 2025-01-25 21:35:09,727 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\api_integration\v1\weather_api.py
# 2025-01-25 21:35:09,727 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\api_integration\v1\finance_api.py
# 2025-01-25 21:35:09,728 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\api_integration\v1\sentiment_api.py
# 2025-01-25 21:35:09,729 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\api_integration\v2
# 2025-01-25 21:35:09,730 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\api_integration\v2\new_feature_api.py
# 2025-01-25 21:35:09,730 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\services
# 2025-01-25 21:35:09,731 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\services\workflows
# 2025-01-25 21:35:09,732 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\services\workflows\approval_service.py
# 2025-01-25 21:35:09,732 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\services\workflows\compliance_service.py
# 2025-01-25 21:35:09,733 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\services\documents
# 2025-01-25 21:35:09,733 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\services\documents\document_service.py
# 2025-01-25 21:35:09,734 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\config
# 2025-01-25 21:35:09,734 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\config\__init__.py
# 2025-01-25 21:35:09,735 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\config\settings.py
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\config\langchain.py
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\config\bureaucracy.py
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\config\logging.yaml
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\config\secrets.json
# 2025-01-25 21:35:09,736 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\middleware
# 2025-01-25 21:35:09,736 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\middleware\auth
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\middleware\auth\authentication.py
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\middleware\auth\authorization.py
# 2025-01-25 21:35:09,736 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\middleware\logging
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\middleware\logging\error_handling.py
# 2025-01-25 21:35:09,736 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\middleware\logging\logging_middleware.py
# 2025-01-25 21:35:09,742 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\middleware\langchain
# 2025-01-25 21:35:09,743 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\middleware\langchain\langchain_middleware.py
# 2025-01-25 21:35:09,743 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\cli
# 2025-01-25 21:35:09,744 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\cli\commands
# 2025-01-25 21:35:09,744 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\cli\commands\agents
# 2025-01-25 21:35:09,745 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\commands\agents\start_agent.py
# 2025-01-25 21:35:09,745 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\commands\agents\stop_agent.py
# 2025-01-25 21:35:09,746 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\commands\agents\list_agents.py
# 2025-01-25 21:35:09,746 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\cli\commands\workflows
# 2025-01-25 21:35:09,747 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\commands\workflows\start_workflow.py
# 2025-01-25 21:35:09,748 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\commands\workflows\approve_task.py
# 2025-01-25 21:35:09,748 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\commands\workflows\generate_report.py
# 2025-01-25 21:35:09,748 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\cli\utils
# 2025-01-25 21:35:09,749 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\utils\config_loader.py
# 2025-01-25 21:35:09,749 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\utils\arg_parser.py
# 2025-01-25 21:35:09,750 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\utils\logger.py
# 2025-01-25 21:35:09,750 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\utils\workflow_helper.py
# 2025-01-25 21:35:09,751 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\utils\report_generator.py
# 2025-01-25 21:35:09,751 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\cli\cli_manager.py
# 2025-01-25 21:35:09,752 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\docs
# 2025-01-25 21:35:09,752 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\docs\API.md
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\docs\LANGCHAIN.md
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\docs\AGENT_INTEROPERABILITY.md
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\docs\KNOWLEDGE_GRAPH.md
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\docs\WORKFLOW_GUIDE.md
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\docs\COMPLIANCE_GUIDE.md
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\docs\SYSTEM_ARCHITECTURE.md
# 2025-01-25 21:35:09,753 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\tests
# 2025-01-25 21:35:09,753 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\tests\agents
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\agents\test_agents.py
# 2025-01-25 21:35:09,753 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\agents\test_agent_collaboration.py
# 2025-01-25 21:35:09,758 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\tests\workflows
# 2025-01-25 21:35:09,760 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\workflows\test_approval_service.py
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\workflows\test_compliance_workflow.py
# 2025-01-25 21:35:09,761 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\tests\langchain
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\langchain\test_langchain_tools.py
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\langchain\test_langchain_chains.py
# 2025-01-25 21:35:09,761 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\tests\integration
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\integration\test_endpoints.py
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\integration\test_document_pipeline.py
# 2025-01-25 21:35:09,761 - INFO - Created directory: C:\Users\sathish\Downloads\AB\backend\tests\functional
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\functional\test_multi_agent_pipeline.py
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\functional\test_toolkits.py
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\tests\conftest.py
# 2025-01-25 21:35:09,761 - INFO - Skipped existing file: C:\Users\sathish\Downloads\AB\backend\main.py
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\requirements.txt
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\Dockerfile
# 2025-01-25 21:35:09,761 - INFO - Created file: C:\Users\sathish\Downloads\AB\backend\.env
# 2025-01-25 21:35:09,761 - INFO - Skipped existing file: C:\Users\sathish\Downloads\AB\backend\README.md
# 2025-01-25 21:35:09,771 - INFO - Created directory: C:\Users\sathish\Downloads\AB\frontend\src\pages
# 2025-01-25 21:35:09,771 - INFO - Created directory: C:\Users\sathish\Downloads\AB\frontend\src\pages\workflows
# 2025-01-25 21:35:09,771 - INFO - Created file: C:\Users\sathish\Downloads\AB\frontend\src\pages\workflows\WorkflowDashboard.jsx
# 2025-01-25 21:35:09,771 - INFO - Created file: C:\Users\sathish\Downloads\AB\frontend\src\pages\workflows\ApprovalPage.jsx
# 2025-01-25 21:35:09,771 - INFO - Created file: C:\Users\sathish\Downloads\AB\frontend\src\pages\workflows\CompliancePage.jsx
# 2025-01-25 21:35:09,771 - INFO - Created directory: C:\Users\sathish\Downloads\AB\frontend\src\api
# 2025-01-25 21:35:09,775 - INFO - Created file: C:\Users\sathish\Downloads\AB\frontend\src\api\workflowApi.js
# 2025-01-25 21:35:09,775 - INFO - Created file: C:\Users\sathish\Downloads\AB\frontend\src\api\complianceApi.js
# 2025-01-25 21:35:09,776 - INFO - Created directory: C:\Users\sathish\Downloads\AB\frontend\tests
# 2025-01-25 21:35:09,777 - INFO - Created directory: C:\Users\sathish\Downloads\AB\frontend\tests\e2e
# 2025-01-25 21:35:09,778 - INFO - Created file: C:\Users\sathish\Downloads\AB\frontend\tests\e2e\test_workflow_dashboard.js
# 2025-01-25 21:35:09,779 - INFO - Created file: C:\Users\sathish\Downloads\AB\frontend\tests\e2e\test_approval_page.js
# 2025-01-25 21:35:09,779 - INFO - Created directory: C:\Users\sathish\Downloads\AB\ci_cd
# 2025-01-25 21:35:09,779 - INFO - Created file: C:\Users\sathish\Downloads\AB\ci_cd\github-actions.yml
# 2025-01-25 21:35:09,779 - INFO - Created file: C:\Users\sathish\Downloads\AB\ci_cd\docker-compose.prod.yml
# 2025-01-25 21:35:09,779 - INFO - Created directory: C:\Users\sathish\Downloads\AB\scripts
# 2025-01-25 21:35:09,779 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\build.sh
# 2025-01-25 21:35:09,783 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\deploy.sh
# 2025-01-25 21:35:09,783 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\start.sh
# 2025-01-25 21:35:09,783 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\stop.sh
# 2025-01-25 21:35:09,783 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\run_tests.sh
# 2025-01-25 21:35:09,783 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\run_workflow.sh
# 2025-01-25 21:35:09,785 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\deploy_staging.sh
# 2025-01-25 21:35:09,785 - INFO - Created file: C:\Users\sathish\Downloads\AB\scripts\deploy_prod.sh
# 2025-01-25 21:35:09,785 - INFO - Created directory: C:\Users\sathish\Downloads\AB\logs
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\logs\.gitignore
# 2025-01-25 21:35:09,786 - INFO - Created directory: C:\Users\sathish\Downloads\AB\utils\common
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\utils\common\report_generator.py
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\utils\common\workflow_helper.py
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\utils\common\config_loader.py
# 2025-01-25 21:35:09,786 - INFO - Created directory: C:\Users\sathish\Downloads\AB\utils\logging
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\utils\logging\structured_logger.py
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\utils\logging\log_rotator.py
# 2025-01-25 21:35:09,786 - INFO - Skipped existing file: C:\Users\sathish\Downloads\AB\README.md
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\LICENSE.md
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\.gitignore
# 2025-01-25 21:35:09,786 - INFO - Created file: C:\Users\sathish\Downloads\AB\.prettierrc
# 2025-01-25 21:35:09,792 - INFO - Created file: C:\Users\sathish\Downloads\AB\.eslintrc.json
# 2025-01-25 21:35:09,792 - INFO - Created file: C:\Users\sathish\Downloads\AB\CHANGELOG.md
# 2025-01-25 21:35:09,792 - INFO - Project structure created at C:\Users\sathish\Downloads\AB
